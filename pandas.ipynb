# %% [markdown]
# # Read csv file

# %%
import pandas as pd
iris=pd.read_csv('iris.csv')
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Show column head  '10 data'

# %%
print(iris.head(10))
# or use 
# print(iris.iloc[0:10])
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# # Show all column

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # Show all data each column

# %%
print(iris["Species"])
# or use 
# print(iris.Species)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
print(iris.iterrows)
# Out:
# <bound method DataFrame.iterrows of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %% [markdown]
# # Craete table

# %%
display(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Create table have checking

# %%
iris.loc[iris['Species'] == 'Iris-setosa']
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %% [markdown]
# # Describing Data

# %%
for Id, Species in iris.iterrows():
    print(Id,":", Species["Species"])
# Out:
# 0 : Iris-setosa
# 1 : Iris-setosa
# 2 : Iris-setosa
# 3 : Iris-setosa
# 4 : Iris-setosa
# 5 : Iris-setosa
# 6 : Iris-setosa
# 7 : Iris-setosa
# 8 : Iris-setosa
# 9 : Iris-setosa
# 10 : Iris-setosa
# 11 : Iris-setosa
# 12 : Iris-setosa
# 13 : Iris-setosa
# 14 : Iris-setosa
# 15 : Iris-setosa
# 16 : Iris-setosa
# 17 : Iris-setosa
# 18 : Iris-setosa
# 19 : Iris-setosa
# 20 : Iris-setosa
# 21 : Iris-setosa
# 22 : Iris-setosa
# 23 : Iris-setosa
# 24 : Iris-setosa
# 25 : Iris-setosa
# 26 : Iris-setosa
# 27 : Iris-setosa
# 28 : Iris-setosa
# 29 : Iris-setosa
# 30 : Iris-setosa
# 31 : Iris-setosa
# 32 : Iris-setosa
# 33 : Iris-setosa
# 34 : Iris-setosa
# 35 : Iris-setosa
# 36 : Iris-setosa
# 37 : Iris-setosa
# 38 : Iris-setosa
# 39 : Iris-setosa
# 40 : Iris-setosa
# 41 : Iris-setosa
# 42 : Iris-setosa
# 43 : Iris-setosa
# 44 : Iris-setosa
# 45 : Iris-setosa
# 46 : Iris-setosa
# 47 : Iris-setosa
# 48 : Iris-setosa
# 49 : Iris-setosa
# 50 : Iris-versicolor
# 51 : Iris-versicolor
# ...

# %% [markdown]
# # Sorting Data

# %%
iris.sort_values('SepalLengthCm')
# iris.sort_values(['Id','SepalLengthCm'], ascending=[0,1])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Adding a column

# %%
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris['testAddColumn']=0
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  testAddColumn
# 0       Iris-setosa              0
# 1       Iris-setosa              0
# 2       Iris-setosa              0
# ...

# %% [markdown]
# # Deleting a column

# %%
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  testAddColumn
# 0       Iris-setosa              0
# 1       Iris-setosa              0
# 2       Iris-setosa              0
# ...

# %%
iris=iris.drop(columns=['testAddColumn'])
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Summing muitiplei columns to create new column

# %%
iris['totalColumns']=iris.iloc[:, 1:5].sum(axis=1)
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  totalColumns
# 0       Iris-setosa          10.2
# 1       Iris-setosa           9.5
# 2       Iris-setosa           9.4
# ...

# %%
iris=iris.drop(columns=['totalColumns'])

# %% [markdown]
# # Rearranging columns

# %%
cols = list(iris.columns)
print(cols)
iris=iris[cols[0:1] + [cols[-1]] + cols[1:5]]
print(iris)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
#       Id         Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0      1     Iris-setosa            5.1           3.5            1.4
# 1      2     Iris-setosa            4.9           3.0            1.4
# 2      3     Iris-setosa            4.7           3.2            1.3
# 3      4     Iris-setosa            4.6           3.1            1.5
# 4      5     Iris-setosa            5.0           3.6            1.4
# ..   ...             ...            ...           ...            ...
# 145  146  Iris-virginica            6.7           3.0            5.2
# 146  147  Iris-virginica            6.3           2.5            5.0
# 147  148  Iris-virginica            6.5           3.0            5.2
# 148  149  Iris-virginica            6.2           3.4            5.4
# 149  150  Iris-virginica            5.9           3.0            5.1
#
#      PetalWidthCm
# 0             0.2
# ...

# %%
iris=pd.read_csv('iris.csv')

# %% [markdown]
# # Create file csv

# %%
iris.to_csv('testCreateFile.csv', index=False)
iris.to_excel('testCreateFile.xlsx', index=False)
iris.to_csv('testCreateFile.txt', index=False, sep='\t')

# %% [markdown]
# # Filtering Data

# %%
newiris=iris.loc[iris.SepalWidthCm == 4.1]
print(newiris)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa

# %% [markdown]
# reset index 'newiris'

# %%
newiris = newiris.reset_index(drop=True)
print(newiris)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  33            5.2           4.1            1.5           0.1  Iris-setosa
